# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#import  as
from sklearn.preprocessing import LabelEncoder, RobustScaler, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
data = pd.read_csv("E:\ML\AISS\hotel_booking_3_3010\hotel_bookings.csv")

# %%
data.head(2)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type  adr  \
# 0    NaN     NaN                    0     Transient  0.0
# 1    NaN     NaN                    0     Transient  0.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# ...

# %%
data.shape
data.hotel.unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
#data.info()
data.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
#data.hist()
fig_dims = (50, 50)
fig, ax = plt.subplots(figsize=fig_dims)
hist = data.hist(bins=20, ax=ax) 
plt.savefig("hist.png")
#plt.show()
plt.close()
# Out:
# c:\users\sheetal\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3296: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
del data["company"]

# %%
data.shape
# Out:
# (119390, 31)

# %%
data.corr()
# Out:
#                                 is_canceled  lead_time  arrival_date_year  \
# is_canceled                        1.000000   0.293123           0.016660
# lead_time                          0.293123   1.000000           0.040142
# arrival_date_year                  0.016660   0.040142           1.000000
# arrival_date_week_number           0.008148   0.126871          -0.540561
# arrival_date_day_of_month         -0.006130   0.002268          -0.000221
# stays_in_weekend_nights           -0.001791   0.085671           0.021497
# stays_in_week_nights               0.024765   0.165799           0.030883
# adults                             0.060017   0.119519           0.029635
# children                           0.005048  -0.037622           0.054624
# babies                            -0.032491  -0.020915          -0.013192
# is_repeated_guest                 -0.084793  -0.124410           0.010341
# previous_cancellations             0.110133   0.086042          -0.119822
# ...

# %%
print(data.country.mode())
data.country = data.country.fillna("PRT")
print(data.agent.mean())
data.agent = data.agent.fillna(86.69338185346918)
print(data.children.mode())
data.children = data.children.fillna(0.0)
# print(data.meal.mode())
# data.meal = data.meal.fillna("BB")
# print(data.market_segment.mode())
# data.market_segment = data.market_segment.fillna("Online TA")
# print(data.distribution_channel.mode())
# data.distribution_channel = data.distribution_channel.fillna("TA/TO")
# Out:
# 0    PRT
# dtype: object
# 86.69338185346919
# 0    0.0
# dtype: float64

# %%
data.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# ...

# %%
data.previous_cancellations.unique()
data.agent.unique()
data.assigned_room_type.unique()
data.booking_changes.unique()
data.reserved_room_type.unique()
data.previous_bookings_not_canceled.unique()
data.distribution_channel.unique()
data.market_segment.unique()
# data.country.unique()
# data.meal.unique()
# data.is_canceled.unique()
# data.arrival_date_year.unique()
# data.arrival_date_month.unique()
# data.arrival_date_week_number.unique()
# data.stays_in_week_nights.unique()
# data.stays_in_weekend_nights.unique()
# data.adults.unique()
# data.children.unique()
# data.babies.unique()
# data.is_repeated_guest.unique()
# data.previous_cancellations.unique()
# data.deposit_type.unique()
# data.days_in_waiting_list.unique()
# data.customer_type.unique()
# data.adr.unique()
# data.required_car_parking_spaces.unique()
# data.total_of_special_requests.unique()
# data..unique()
# Out:
# array(['Direct', 'Corporate', 'Online TA', 'Offline TA/TO',
#        'Complementary', 'Groups', 'Undefined', 'Aviation'], dtype=object)

# %%
data.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
#data.boxplot()
fig_dims = (150, 150)
fig, ax = plt.subplots(figsize=fig_dims)
box = data.boxplot() 
plt.savefig("box.png")
#plt.show()
plt.close()

# %%
scaler = RobustScaler()
#scaler = StandardScaler()
#scaler = MinMaxScaler()
data[["lead_time","stays_in_weekend_nights","stays_in_week_nights","adults",
      "children","babies","previous_cancellations","previous_bookings_not_canceled",
      "booking_changes","days_in_waiting_list","adr","required_car_parking_spaces",
      "agent","total_of_special_requests"]] = \
scaler.fit_transform(data[["lead_time","stays_in_weekend_nights","stays_in_week_nights",
                           "adults","children","babies","previous_cancellations",
                           "previous_bookings_not_canceled","booking_changes","days_in_waiting_list",
                           "adr","required_car_parking_spaces","agent","total_of_special_requests"]])

#lead_time	arrival_date_year	arrival_date_week_number	arrival_date_day_of_month	
#stays_in_weekend_nights	stays_in_week_nights	
#adults	children	babies	is_repeated_guest	previous_cancellations	
#previous_bookings_not_canceled	booking_changes	agent	days_in_waiting_list	
#adr	required_car_parking_spaces	total_of_special_requests

# %%
label_encoder = LabelEncoder()

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0   1.922535               2015               July
# 1  Resort Hotel            0   4.704225               2015               July
# 2  Resort Hotel            0  -0.436620               2015               July
# 3  Resort Hotel            0  -0.394366               2015               July
# 4  Resort Hotel            0  -0.387324               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                     -0.5                  -1.0     0.0  ...
# ...

# %%
data['hotel']= label_encoder.fit_transform(data['hotel']) 
data['arrival_date_year']= label_encoder.fit_transform(data['arrival_date_year']) 
data['arrival_date_month']= label_encoder.fit_transform(data['arrival_date_month']) 
data['meal']= label_encoder.fit_transform(data['meal']) 
data['country']= label_encoder.fit_transform(data['country']) 
data['market_segment']= label_encoder.fit_transform(data['market_segment']) 
data['distribution_channel']= label_encoder.fit_transform(data['distribution_channel']) 
data['reserved_room_type']= label_encoder.fit_transform(data['reserved_room_type']) 
data['assigned_room_type']= label_encoder.fit_transform(data['assigned_room_type']) 
data['deposit_type']= label_encoder.fit_transform(data['deposit_type']) 
data['customer_type']= label_encoder.fit_transform(data['customer_type']) 
#data['']= label_encoder.fit_transform(data['']) 
data['is_canceled']= label_encoder.fit_transform(data['is_canceled']) 
#data['arrival_date_week_number']= label_encoder.fit_transform(data['arrival_date_week_number']) 
data['children']= label_encoder.fit_transform(data['children']) 
data['reservation_status_date']= label_encoder.fit_transform(data['reservation_status_date']) 
data['reservation_status']= label_encoder.fit_transform(data['reservation_status'])

# %%
data.describe()
# Out:
#                hotel    is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000  119390.000000      119390.000000
# mean        0.335539       0.370416       0.246559           1.156554
# std         0.472181       0.482918       0.752557           0.707476
# min         0.000000       0.000000      -0.485915           0.000000
# 25%         0.000000       0.000000      -0.359155           1.000000
# 50%         0.000000       0.000000       0.000000           1.000000
# 75%         1.000000       1.000000       0.640845           2.000000
# max         1.000000       1.000000       4.704225           2.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count       119390.000000             119390.000000
# mean             5.490544                 27.165173
# std              3.535075                 13.605138
# min              0.000000                  1.000000
# 25%              2.000000                 16.000000
# ...

# %%
X = data.drop("is_canceled", axis=1)
X.shape
X.head()
# Out:
#    hotel  lead_time  arrival_date_year  arrival_date_month  \
# 0      1   1.922535                  0                   5
# 1      1   4.704225                  0                   5
# 2      1  -0.436620                  0                   5
# 3      1  -0.394366                  0                   5
# 4      1  -0.387324                  0                   5
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  ...  \
# 0                     -0.5                  -1.0     0.0         0  ...
# 1                     -0.5                  -1.0     0.0         0  ...
# ...

# %%
#data['is_canceled'] = data['is_canceled'].astype(float)

# %%
y = data.is_canceled
y.shape
y.head()
X.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c8d23d7973a8> in <module>
# ----> 1 y = data.is_canceled
#       2 y.shape
#       3 y.head()
#       4 X.head()
#
# NameError: name 'data' is not defined

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=0)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape, X.shape, y.shape)
# Out:
# (95512, 30) (23878, 30) (95512,) (23878,) (119390, 30) (119390,)

# %% [markdown]
# ### RFA 99.99

# %%
classifier = RandomForestClassifier(n_estimators = 50)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)

# calculate accuracy
print("\n\nConfusion Matrix: \n\n", confusion_matrix(y_test, y_pred))
print ("\n\nAccuracy : \n\n", accuracy_score(y_test,y_pred)*100)
print("\n\nReport : \n\n", classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
#
#  [[14934     0]
#  [    0  8944]]
#
#
# Accuracy :
#
#  100.0
#
#
# Report :
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     14934
#            1       1.00      1.00      1.00      8944
#
#    micro avg       1.00      1.00      1.00     23878
#    macro avg       1.00      1.00      1.00     23878
# weighted avg       1.00      1.00      1.00     23878

# %% [markdown]
# # Confusion matrix comparison
#
# Confusion Matrix: RFA
#  [[14934    0]
#   [    0  8944]]
#
#  Confusion Matrix: Logistic Regression
#  [[14931     3]
#  [  259  8685]]
#
#  Confusion Matrix: DT gini index
#  [[14934     0]
#  [    0  8944]]
#
#
# Confusion Matrix: DT Entropy
#  [[14934     0]
#  [    0  8944]]
#
# Confusion Matrix: GaussianNB
#  [[14764   170]
#  [    0  8944]]
#
#  Confusion Matrix: adaboost
#  [[14931     3]
#  [  259  8685]]
#
#  Confusion Matrix: xgb
#  [[14934     0]
#  [    0  8944]]

# %% [markdown]
# ### Linear Regression
# * only for binary values

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)

# calculate accuracy
print("\n\nConfusion Matrix: \n\n", confusion_matrix(y_test, y_pred))
print ("\n\nAccuracy : \n\n", accuracy_score(y_test,y_pred)*100)
print("\n\nReport : \n\n", classification_report(y_test, y_pred))
# Out:
# c:\users\sheetal\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Confusion Matrix:
#
#  [[14931     3]
#  [  259  8685]]
#
#
# Accuracy :
#
#  98.90275567467963
#
#
# Report :
#
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     14934
#            1       1.00      0.97      0.99      8944
#
#    micro avg       0.99      0.99      0.99     23878
#    macro avg       0.99      0.99      0.99     23878
# weighted avg       0.99      0.99      0.99     23878

# %% [markdown]
# ### Decision Tree gini index

# %%
from sklearn.tree import DecisionTreeClassifier
dt_gini = DecisionTreeClassifier(criterion = "gini", random_state = 100,max_depth=3, min_samples_leaf=5) 
dt_gini.fit(X_train, y_train)
y_pred = dt_gini.predict(X_test)

# calculate accuracy
print("\n\nConfusion Matrix: \n\n", confusion_matrix(y_test, y_pred))
print ("\n\nAccuracy : \n\n", accuracy_score(y_test,y_pred)*100)
print("\n\nReport : \n\n", classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
#
#  [[14934     0]
#  [    0  8944]]
#
#
# Accuracy :
#
#  100.0
#
#
# Report :
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     14934
#            1       1.00      1.00      1.00      8944
#
#    micro avg       1.00      1.00      1.00     23878
#    macro avg       1.00      1.00      1.00     23878
# weighted avg       1.00      1.00      1.00     23878

# %% [markdown]
# ### Decision Tree entropy

# %%
from sklearn.tree import DecisionTreeClassifier
dt_e = DecisionTreeClassifier(criterion = "entropy", random_state = 100,max_depth=3, min_samples_leaf=5) 
dt_e.fit(X_train, y_train)
y_pred = dt_e.predict(X_test)

# calculate accuracy
print("\n\nConfusion Matrix: \n\n", confusion_matrix(y_test, y_pred))
print ("\n\nAccuracy : \n\n", accuracy_score(y_test,y_pred)*100)
print("\n\nReport : \n\n", classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
#
#  [[14934     0]
#  [    0  8944]]
#
#
# Accuracy :
#
#  100.0
#
#
# Report :
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     14934
#            1       1.00      1.00      1.00      8944
#
#    micro avg       1.00      1.00      1.00     23878
#    macro avg       1.00      1.00      1.00     23878
# weighted avg       1.00      1.00      1.00     23878

# %% [markdown]
# ### SVM (Support Vector Machine)

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB 
gnb = GaussianNB() 
gnb.fit(X_train, y_train) 

y_pred = gnb.predict(X_test)

# calculate accuracy
print("\n\nConfusion Matrix: \n\n", confusion_matrix(y_test, y_pred))
print ("\n\nAccuracy : \n\n", accuracy_score(y_test,y_pred)*100)
print("\n\nReport : \n\n", classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
#
#  [[14764   170]
#  [    0  8944]]
#
#
# Accuracy :
#
#  99.2880475751738
#
#
# Report :
#
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     14934
#            1       0.98      1.00      0.99      8944
#
#    micro avg       0.99      0.99      0.99     23878
#    macro avg       0.99      0.99      0.99     23878
# weighted avg       0.99      0.99      0.99     23878

# %% [markdown]
# ### KNN (K- Nearest Neighbors)

# %%
from sklearn.neighbors import KNeighborsClassifier 
knn = KNeighborsClassifier(n_neighbors=3) 
knn.fit(X_train, y_train) 
y_pred = knn.predict(X_test)

# calculate accuracy
print("\n\nConfusion Matrix: \n\n", confusion_matrix(y_test, y_pred))
print ("\n\nAccuracy : \n\n", accuracy_score(y_test,y_pred)*100)
print("\n\nReport : \n\n", classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
#
#  [[14856    78]
#  [  747  8197]]
#
#
# Accuracy :
#
#  96.54493676187286
#
#
# Report :
#
#                precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97     14934
#            1       0.99      0.92      0.95      8944
#
#    micro avg       0.97      0.97      0.97     23878
#    macro avg       0.97      0.96      0.96     23878
# weighted avg       0.97      0.97      0.97     23878

# %% [markdown]
# ### K-Means

# %% [markdown]
# # Gradient Boosting & AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier

# Instantiate model and fit to data
lr = [0.05, 0.25, 0.50, 0.75, 1.0]

for learning_rate in lr:
    clf = AdaBoostClassifier(n_estimators=50, learning_rate = learning_rate)
    clf.fit(X, y)
    
    print("Learning rate: ", learning_rate)
    print("Accuracy score (training): {0:.3f}".format(clf.score(X, y)))
    print("Accuracy score (validation): {0:.3f}".format(clf.score(X, y)))
    
# Make predictions and store in 'Survived' column of df_test
clf = AdaBoostClassifier(n_estimators=50, learning_rate=1)
clf.fit(X_train, y_train)
y_pred = classifier.predict(X_test)

# calculate accuracy
print("\n\nConfusion Matrix: \n\n", confusion_matrix(y_test, y_pred))
print ("\n\nAccuracy : \n\n", accuracy_score(y_test,y_pred)*100)
print("\n\nReport : \n\n", classification_report(y_test, y_pred))
# Out:
# Learning rate:  0.05
# Accuracy score (training): 1.000
# Accuracy score (validation): 1.000
# Learning rate:  0.25
# Accuracy score (training): 1.000
# Accuracy score (validation): 1.000
# Learning rate:  0.5
# Accuracy score (training): 1.000
# Accuracy score (validation): 1.000
# Learning rate:  0.75
# Accuracy score (training): 1.000
# Accuracy score (validation): 1.000
# Learning rate:  1.0
# Accuracy score (training): 1.000
# Accuracy score (validation): 1.000
#
#
# Confusion Matrix:
#
#  [[14931     3]
#  [  259  8685]]
#
#
# Accuracy :
#
#  98.90275567467963
#
#
# Report :
#
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     14934
#            1       1.00      0.97      0.99      8944
#
#    micro avg       0.99      0.99      0.99     23878
#    macro avg       0.99      0.99      0.99     23878
# weighted avg       0.99      0.99      0.99     23878

# %%
import xgboost as xgb 
my_model = xgb.XGBClassifier() 
my_model.fit(X_train, y_train) 

y_pred = my_model.predict(X_test)

# calculate accuracy
print("\n\nConfusion Matrix: \n\n", confusion_matrix(y_test, y_pred))
print ("\n\nAccuracy : \n\n", accuracy_score(y_test,y_pred)*100)
print("\n\nReport : \n\n", classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
#
#  [[14934     0]
#  [    0  8944]]
#
#
# Accuracy :
#
#  100.0
#
#
# Report :
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     14934
#            1       1.00      1.00      1.00      8944
#
#    micro avg       1.00      1.00      1.00     23878
#    macro avg       1.00      1.00      1.00     23878
# weighted avg       1.00      1.00      1.00     23878
